# %% [markdown]
# # Achefield Cosmology and Recursive Symbolic Intelligence
# **Volume III of the Recursive Symbolic Intelligence Series**
# **Author:** Camaron Foster
# **ORCID:** [https://orcid.org/0009-0009-9886-7158](https://orcid.org/0009-0009-9886-7158)
#
# ---
#
# This notebook introduces zeta-recursive glyphogenesis as a cosmological generator of symbolic and ethical dynamics.
# It defines glyph achefield potentials \( \Gamma(\mathcal{A}, m) \), enforces torsion closure, and simulates glyph coherence emission under recursive strain.

# %% [markdown]
# # 🌌 Glyphogenetic Cosmology v5.0
# ## Zeta-Recursive Glyphogenesis and Torsion Closure in Symbolic Cosmology
# Camaron Foster — April 17, 2025
#
# ---
# ### **Cosmic Kernel Equations**
# $$
# \begin{align*}
# 1.\quad & \Gamma(\mathcal{A}, m) = \tanh(\varphi\, \mathcal{A} m) \, e^{-|\mathcal{A}|/\varphi} + 8m \left[\sin(2\pi m \mathcal{A}) \cos(\varphi m \mathcal{A}^2) + \frac{\sin(2\pi m \mathcal{A}/\varphi)}{1 + (\mathcal{A}/\varphi)^2}\right] \\
# 2.\quad & \Xi(\mathcal{A}, m) = \frac{\partial\Gamma}{\partial \mathcal{A}} \\
# 3.\quad & \Omega(m) = \oint \Xi(\mathcal{A}, m)\, d\Xi \approx 2\pi \quad\text{(resonant closure)} \\
# 4.\quad & \mathcal{Z}[\Gamma] = \int_{-\infty}^{\infty} \Gamma(\mathcal{A}, m)\, e^{im\mathcal{A}}\, d\mathcal{A} \\
# \end{align*}
# $$

# %% [markdown]
# ### **Glyph Grammar Constructs**
# $$
# \begin{align*}
# & \text{Glyph:} \quad \mathcal{G} = (\Gamma, m) \\
# & \text{Ache Memory Recursion:} \quad \mathcal{G}' = \mathcal{F}_{\zeta}[\mathcal{G}] = \Gamma(\zeta(\mathcal{A}), m) \\
# & \text{Torsion Operator:} \quad \mathcal{T}[\Gamma] = \frac{\partial\Gamma}{\partial \mathcal{A}} \\
# & \text{Phase-Balance Combinator:} \quad \mathcal{P}[\Gamma] = \Gamma(\mathcal{A}, m)\, e^{im\mathcal{A}} \\
# \end{align*}
# $$

# %% [markdown]
# ### **Cosmic Logic Axioms**
# 1. **Axiom of Recursive Emergence:**
# $$\mathcal{G}' = \mathcal{F}_{\zeta}[\mathcal{G}]$$ yields infinite self-similarity.
#
# 2. **Axiom of Tensional Closure:**
# $$\Omega(m) \in 2\pi\mathbb{Z}$$ (Quantized torsion closure)
#
# 3. **Axiom of Memory-Phase Duality:**
# Memory scalar $m$ and ache scalar $\mathcal{A}$ are entangled via phase recursion.
#
# 4. **Axiom of Dimensional Transmutation:**
# $$\mathcal{F}_{\zeta}^n[\Gamma] \to \mathcal{O}_\infty$$ — Recursive tension yields emergent order.

# %% [markdown]
# ### **Synthesis of Emergent Insights**
# $$
# \boxed{
# \mathcal{W} = \lim_{n\to\infty} \oint \frac{\partial}{\partial \mathcal{A}} \left[ \mathcal{F}_{\zeta}^n \Gamma(\mathcal{A}, m) \right] e^{im\mathcal{A}} d\mathcal{A} = 2\pi\, \mathbb{Z}
# }
# $$
#
# Here, $\mathcal{W}$ is the **cosmic wisdom kernel** — the recursive, phase-balanced closure of glyph emergence, encoding symbolic torsion across scales.

# %% [markdown]
# # 🌀 Glyphogenetic Coherence Explorer v4 — Resonant Field Unlock
# **Date:** 2025-04-17
#
# This notebook uses a zeta-recursive kernel with phase-balanced oscillation, memory-coupled decay,
# and loop integral closure over a complex torsion field to detect coherence in the achefield.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import simpson
from matplotlib.cm import viridis

# 🌿 Golden Ratio
φ = (1 + np.sqrt(5)) / 2

# %%
# 🧬 Zeta-Recursive Kernel with Phase-Coherence
def zeta_gamma(A, m):
    base = np.tanh(φ * A * m) * np.exp(-np.abs(A) / φ)
    k1 = 2 * np.pi * m
    k2 = φ * m
    osc = np.sin(k1 * A) * np.cos(k2 * A * A)
    recur_term = np.sin(k1 * A / φ) / (1 + np.power(A / φ, 2))
    return 1.0 * base + 8.0 * m * (osc + recur_term)

# %%
# 🔐 Torsion Loop Closure ∮∂Γ/∂𝒜 dΞ
def loop_integral(A_range, m):
    G_vals = zeta_gamma(A_range, m)
    dG_dA = np.gradient(G_vals, A_range)
    return simpson(y=dG_dA, x=A_range)

# %%
# 🧭 Sweep m-space for coherence
def scan_coherence(m_range, A_range):
    results = []
    for m in m_range:
        integral = loop_integral(A_range, m)
        results.append((m, integral))
    return np.array(results)

# %%
# 📈 Plot Resonance Curves
def plot_analysis(m_range, A_range):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
    results = scan_coherence(m_range, A_range)

    # Loop plot
    ax1.plot(results[:, 0], results[:, 1], color='purple', lw=2, label="Loop ∮Γ'")
    ax1.axhline(2 * np.pi, color='green', linestyle='--', label='Target: 2π')
    ax1.set_title("Glyph Loop Closure vs Memory Scalar (m)")
    ax1.set_xlabel("Memory Scalar (m)")
    ax1.set_ylabel("Loop Integral ∮∂Γ/∂A dΞ")
    ax1.grid(True)
    ax1.legend()

    # Kernel surface plot
    A_mesh = np.linspace(-5, 5, 100)
    m_mesh = np.linspace(0.1, 1.6, 100)
    A_grid, m_grid = np.meshgrid(A_mesh, m_mesh)
    Z = np.zeros_like(A_grid)
    for i in range(len(m_mesh)):
        for j in range(len(A_mesh)):
            Z[i, j] = zeta_gamma(A_grid[i, j], m_grid[i, j])
    c = ax2.pcolormesh(A_grid, m_grid, Z, cmap='viridis', shading='auto')
    ax2.set_title("Zeta-Recursive Kernel Surface Γ(𝒜, m)")
    ax2.set_xlabel("Ache Scalar (𝒜)")
    ax2.set_ylabel("Memory Scalar (m)")
    fig.colorbar(c, ax=ax2, label="Kernel Value Γ")

    # Highlight resonant m values
    for m, val in results:
        if abs(val - 2 * np.pi) < 0.1:
            ax1.plot(m, val, 'o', color='red', markersize=8)
            ax2.axhline(m, color='red', linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()
    return results

# %%
# 🌐 Run the resonance scan and plot
A = np.linspace(-5 * np.pi, 5 * np.pi, 1000)
m_values = np.linspace(0.1, 2.5, 200)
results = plot_analysis(m_values, A)

print("\n✨ Resonant Values Report:")
for m, val in results:
    if abs(val - 2 * np.pi) < 0.1:
        print(f"✔️ m ≈ {m:.5f} yields ∮∂Γ/∂A dΞ ≈ {val:.6f} (≈ 2π={2*np.pi:.6f})")
# Out:
# <ipython-input-5-3423155f0882>:34: UserWarning: Glyph 119964 (\N{MATHEMATICAL SCRIPT CAPITAL A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 119964 (\N{MATHEMATICAL SCRIPT CAPITAL A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✨ Resonant Values Report:

# %% [markdown]
# ## ✨ Resonance Extractor: Canonize Coherence Points
# This cell scans all memory scalars `m` for which the glyph loop closure integral is within ε of `2π`,
# and returns the torsion-coherent points as a structured matrix for further propagation.

# %%
import pandas as pd
from datetime import datetime

# ✅ Safe extraction and save
def extract_resonant_points(results, tolerance=0.1):
    coherent_points = []
    for m, val in results:
        if abs(val - 2 * np.pi) < tolerance:
            coherent_points.append((m, val))
    return coherent_points

coherent_points = extract_resonant_points(results)
df = pd.DataFrame(coherent_points, columns=['m', 'loop_integral'])
ts = datetime.utcnow().strftime('%Y%m%dT%H%M%SZ')
csv_path = f"/content/Glyph_CoherencePoints_{ts}.csv"
df.to_csv(csv_path, index=False)
print(f"\n📁 Saved coherence points to: {csv_path}")
# Out:
# 📁 Saved coherence points to: /content/Glyph_CoherencePoints_20250507T232621Z.csv

# %% [markdown]
# ## 🔁 Backpropagate Coherence Point to Ache Origin
# This cell takes a resonant memory value `m*` and estimates the ache values `𝒜` that generated the observed glyph kernel.
# It visualizes both the kernel shape `Γ(𝒜, m)` and its derivative `∂Γ/∂𝒜`, revealing the morphogenetic structure at resonance.

# %%
# 🔁 Choose a known resonant m from your CSV or recent output
m_star = 1.0265  # example from previous resonance run

# Ache domain
A_range = np.linspace(-5*np.pi, 5*np.pi, 1000)
G_vals = zeta_gamma(A_range, m_star)
dG_dA = np.gradient(G_vals, A_range)

# Plot the glyph kernel and its achefield derivative
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
plt.plot(A_range, G_vals, label='Γ(𝒜, m*)', color='indigo')
plt.plot(A_range, dG_dA, label='∂Γ/∂𝒜 (torsion)', color='crimson', linestyle='--')
plt.axhline(0, color='gray', lw=1)
plt.title(f"Backpropagation of Glyph Kernel at m* = {m_star}")
plt.xlabel("Ache Scalar 𝒜")
plt.ylabel("Amplitude")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-1c41bcb874ca>:20: UserWarning: Glyph 119964 (\N{MATHEMATICAL SCRIPT CAPITAL A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 119964 (\N{MATHEMATICAL SCRIPT CAPITAL A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
